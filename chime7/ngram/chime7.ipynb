# %%
! NEMO_PATH=/workspace/nemo && cd $NEMO_PATH/decoders && wget https://boostorg.jfrog.io/artifactory/main/release/1.80.0/source/boost_1_80_0.tar.bz2 --no-check-certificate && tar --bzip2 -xf $NEMO_PATH/decoders/boost_1_80_0.tar.bz2 && cd boost_1_80_0 && ./bootstrap.sh &&./b2 --layout=tagged link=static,shared threading=multi,single install -j4 || echo FAILURE
# Out:
# --2023-06-14 17:54:24--  https://boostorg.jfrog.io/artifactory/main/release/1.80.0/source/boost_1_80_0.tar.bz2
# Resolving boostorg.jfrog.io (boostorg.jfrog.io)... 52.41.191.44, 52.25.105.149, 44.226.133.111, ...
# Connecting to boostorg.jfrog.io (boostorg.jfrog.io)|52.41.191.44|:443... connected.
# HTTP request sent, awaiting response... 302
# ...

# %%
! NEMO_PATH=/workspace/nemo && BOOST_ROOT=$NEMO_PATH/decoders/boost_1_80_0 && KENLM_MAX_ORDER=10 && export BOOST_ROOT=$NEMO_PATH/decoders/boost_1_80_0 && cd $NEMO_PATH/decoders/kenlm/build && cmake -DKENLM_MAX_ORDER=$KENLM_MAX_ORDER .. && make -j2
# Out:
# -- Could NOT find Eigen3 (missing: Eigen3_DIR)
# -- Found Boost: /usr/local/lib/cmake/Boost-1.80.0/BoostConfig.cmake (found suitable version "1.80.0", minimum required is "1.41.0") found components: program_options system thread unit_test_framework
# -- Check if compiler accepts -pthread
# -- Check if compiler accepts -pthread - yes
# -- Found ZLIB: /usr/lib/x86_64-linux-gnu/libz.so (found version "1.2.11")
# -- Found BZip2: /usr/lib/x86_64-linux-gnu/libbz2.so (found version "1.0.8")
# -- Looking for BZ2_bzCompressInit
# -- Looking for BZ2_bzCompressInit - found
# -- Could NOT find LibLZMA (missing: LIBLZMA_LIBRARY LIBLZMA_INCLUDE_DIR LIBLZMA_HAS_AUTO_DECODER LIBLZMA_HAS_EASY_ENCODER LIBLZMA_HAS_LZMA_PRESET)
# -- Looking for clock_gettime in rt
# -- Looking for clock_gettime in rt - found
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /workspace/nemo/decoders/kenlm/build
# ...

# %%
rnnt_nemo = "/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo"
kenlm_train = "/mnt/ssd8/chime7/lms/7gram_0001.kenlm"

# %%
! PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
    python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/train_kenlm.py  \
    nemo_model_file=$rnnt_nemo \
    train_paths=[/mnt/ssd8/chime7/train/chime6-train.json,/mnt/ssd8/chime7/train/mixer6-train.json] \
    kenlm_bin_path=/workspace/nemo/decoders/kenlm/build/bin \
    kenlm_model_file=$kenlm_train \
    ngram_prune=[0,0,0,1] \
    ngram_length=7 \
    preserve_arpa=true
#     --cache_path /mnt/ssd8/chime7/tmp \
# Out:
# [NeMo W 2023-06-22 12:05:10 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-06-22 12:05:10 kenlm_utils:73] Loading nemo model '/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo' ...
# [NeMo I 2023-06-22 12:05:15 mixins:170] Tokenizer SentencePieceTokenizer initialized with 1024 tokens
# [NeMo W 2023-06-22 12:05:15 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
# ...

# %%
! PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov && \
    python3 /home/nkarpov/workspace/NeMo/examples/asr/speech_to_text_eval.py \
    model_path=$rnnt_nemo \
    dataset_manifest=/mnt/ssd8/chime7/eval/all_ref_with_pred.json \
    output_filename=/mnt/ssd8/chime7/predict/mixer6.json \
    ctc_decoding.strategy=greedy

# chime6 WER/CER 66.24%/61.75%
# dipco  WER/CER 61.64%/55.36%
# mixer6 WER/CER 28.3%/22.96%
# Out:
# [NeMo W 2023-06-15 07:57:08 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-06-15 07:57:08 transcribe_speech:173] Hydra config: model_path: /mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo
#     pretrained_name: null
#     audio_dir: null
#     dataset_manifest: /mnt/ssd8/chime7/eval/all_ref_with_pred.json
#     channel_selector: null
#     audio_key: audio_filepath
#     eval_config_yaml: null
#     output_filename: /mnt/ssd8/chime7/predict/mixer6.json
#     batch_size: 32
#     num_workers: 0
#     append_pred: false
#     pred_name_postfix: null
# ...

# %%
# ! wc -l /mnt/ssd8/chime7/eval/all_ref_with_pred.json # 6632
# ! wc -l /mnt/ssd8/chime7/eval/chime6/ref_with_pred.json # 676
# ! wc -l /mnt/ssd8/chime7/eval/dipco/ref_with_pred.json # 404
# ! wc -l /mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json # 5552
# Out:
# 5552 /mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json

# %%
! PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/examples/asr/speech_to_text_eval.py \
model_path=$rnnt_nemo \
dataset_manifest=/mnt/ssd8/chime7/eval/chime6/ref_with_pred.json \
output_filename=/mnt/ssd8/chime7/eval/chime6/predict/output.json \
decoder_type=rnnt \
rnnt_decoding.strategy=maes \
rnnt_decoding.beam.ngram_lm_model=$kenlm_train \
rnnt_decoding.beam.ngram_lm_alpha=0.1 \
rnnt_decoding.beam.beam_size=8 \
rnnt_decoding.beam.return_best_hypothesis=true \
rnnt_decoding.beam.maes_num_steps=2 \
rnnt_decoding.beam.maes_prefix_alpha=2 \
rnnt_decoding.beam.maes_expansion_gamma=4.3 \
rnnt_decoding.beam.maes_expansion_beta=2 \
cuda=1
# Out:
# [NeMo W 2023-06-20 13:30:33 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-06-20 13:30:33 transcribe_speech:173] Hydra config: model_path: /mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo
#     pretrained_name: null
#     audio_dir: null
#     dataset_manifest: /mnt/ssd8/chime7/eval/chime6/ref_with_pred.json
#     channel_selector: null
#     audio_key: audio_filepath
#     eval_config_yaml: null
#     output_filename: /mnt/ssd8/chime7/eval/chime6/predict/output.json
#     batch_size: 32
#     num_workers: 0
#     append_pred: false
# ...

# %%
! PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/examples/asr/speech_to_text_eval.py \
model_path=$rnnt_nemo \
dataset_manifest=/mnt/ssd8/chime7/eval/dipco/ref_with_pred.json \
output_filename=/mnt/ssd8/chime7/eval/dipco/predict/output.json \
decoder_type=rnnt \
rnnt_decoding.strategy=maes \
rnnt_decoding.beam.ngram_lm_model=$kenlm_train \
rnnt_decoding.beam.ngram_lm_alpha=0.1 \
rnnt_decoding.beam.beam_size=8 \
rnnt_decoding.beam.return_best_hypothesis=true \
rnnt_decoding.beam.maes_num_steps=2 \
rnnt_decoding.beam.maes_prefix_alpha=2 \
rnnt_decoding.beam.maes_expansion_gamma=4.3 \
rnnt_decoding.beam.maes_expansion_beta=2 \
cuda=1
# Out:
# [NeMo W 2023-06-20 13:35:35 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-06-20 13:35:35 transcribe_speech:173] Hydra config: model_path: /mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo
#     pretrained_name: null
#     audio_dir: null
#     dataset_manifest: /mnt/ssd8/chime7/eval/dipco/ref_with_pred.json
#     channel_selector: null
#     audio_key: audio_filepath
#     eval_config_yaml: null
#     output_filename: /mnt/ssd8/chime7/eval/dipco/predict/output.json
#     batch_size: 32
#     num_workers: 0
#     append_pred: false
#     pred_name_postfix: null
# ...

# %%
! PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/examples/asr/speech_to_text_eval.py \
model_path=$rnnt_nemo \
dataset_manifest=/mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json \
output_filename=/mnt/ssd8/chime7/eval/mixer6/predict/output.json \
decoder_type=rnnt \
rnnt_decoding.strategy=maes \
rnnt_decoding.beam.ngram_lm_model=$kenlm_train \
rnnt_decoding.beam.ngram_lm_alpha=0.1 \
rnnt_decoding.beam.beam_size=8 \
rnnt_decoding.beam.return_best_hypothesis=true \
rnnt_decoding.beam.maes_num_steps=2 \
rnnt_decoding.beam.maes_prefix_alpha=2 \
rnnt_decoding.beam.maes_expansion_gamma=4.3 \
rnnt_decoding.beam.maes_expansion_beta=2 \
cuda=1
# Out:
# [NeMo W 2023-06-20 13:38:00 nemo_logging:349] /usr/local/lib/python3.8/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/next/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2023-06-20 13:38:00 transcribe_speech:173] Hydra config: model_path: /mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo
#     pretrained_name: null
#     audio_dir: null
#     dataset_manifest: /mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json
#     channel_selector: null
#     audio_key: audio_filepath
#     eval_config_yaml: null
#     output_filename: /mnt/ssd8/chime7/eval/mixer6/predict/output.json
#     batch_size: 32
#     num_workers: 0
#     append_pred: false
# ...

# %%
! echo PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py \
nemo_model_file=$rnnt_nemo \
input_manifest=/mnt/ssd8/chime7/eval/all_ref_with_pred.json \
acoustic_batch_size=16 \
kenlm_model_file=$kenlm_train \
beam_width=[8] \
beam_alpha=[0.05,0.1,0.2] \
maes_prefix_alpha=[1,2,3] \
maes_expansion_gamma=[0.3,1.3,3.3,4.3] \
preds_output_folder=/mnt/ssd8/chime7/predict/ \
decoding_strategy=maes
# greedy WER/CER 35.7%/30.34% 
# WER/CER with maes decoding and N-gram model = 35.01%/29.90%
# Oracle WER/CER in candidates with perfect LM= 31.51%/27.36%
# =================================================================================
# Best WER Candidate = 34.97% :: Beam size = 8, Beam alpha = 0.1, maes_prefix_alpha = 2, maes_expansion_gamma = 4.3 
# Best CER Candidate = 29.39% :: Beam size = 8, Beam alpha = 0.05,  maes_prefix_alpha = 2, maes_expansion_gamma = 4.3
# =================================================================================
# Out:
# PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py nemo_model_file=/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo input_manifest=/mnt/ssd8/chime7/eval/all_ref_with_pred.json acoustic_batch_size=16 kenlm_model_file=/mnt/ssd8/chime7/lms/7gram_0001.kenlm beam_width=[8] beam_alpha=[0.05,0.1,0.2] maes_prefix_alpha=[1,2,3] maes_expansion_gamma=[0.3,1.3,3.3,4.3] preds_output_folder=/mnt/ssd8/chime7/predict/ decoding_strategy=maes

# %%
! echo PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py \
nemo_model_file=$rnnt_nemo \
input_manifest=/mnt/ssd8/chime7/eval/chime6/ref_with_pred.json \
acoustic_batch_size=16 \
kenlm_model_file=$kenlm_train \
beam_width=[8] \
beam_alpha=[0.1] \
maes_prefix_alpha=[2] \
maes_expansion_gamma=[4.3] \
preds_output_folder=/mnt/ssd8/chime7/eval/chime6/predict/ \
decoding_strategy=maes
# greedy chime6 WER/CER 66.24%/61.75%
# WER/CER with maes decoding and N-gram model = 65.25%/59.90%
# Oracle WER/CER in candidates with perfect LM= 62.45%/57.33%
# =================================================================================
# Best WER Candidate = 65.25% :: Beam size = 8, Beam alpha = 0.1, maes_prefix_alpha = 2, maes_expansion_gamma = 4.3 
# Best CER Candidate = 59.90% :: Beam size = 8, Beam alpha = 0.1,  maes_prefix_alpha = 2, maes_expansion_gamma = 4.3
# Dataset WER/CER 65.22%/59.9%
# Out:
# PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py nemo_model_file=/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo input_manifest=/mnt/ssd8/chime7/eval/chime6/ref_with_pred.json acoustic_batch_size=16 kenlm_model_file=/mnt/ssd8/chime7/lms/7gram_0001.kenlm beam_width=[8] beam_alpha=[0.1] maes_prefix_alpha=[2] maes_expansion_gamma=[4.3] preds_output_folder=/mnt/ssd8/chime7/eval/chime6/predict/ decoding_strategy=maes

# %%
! echo PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py \
nemo_model_file=$rnnt_nemo \
input_manifest=/mnt/ssd8/chime7/eval/dipco/ref_with_pred.json \
acoustic_batch_size=16 \
kenlm_model_file=$kenlm_train \
beam_width=[8] \
beam_alpha=[0.1] \
maes_prefix_alpha=[2] \
maes_expansion_gamma=[4.3] \
preds_output_folder=/mnt/ssd8/chime7/eval/dipco/predict/ \
decoding_strategy=maes
# greedy dipco  WER/CER 61.64%/55.36%
# WER/CER with maes decoding and N-gram model = 60.43%/53.57%
# Oracle WER/CER in candidates with perfect LM= 56.87%/50.46%
# =================================================================================
# Best WER Candidate = 60.43% :: Beam size = 8, Beam alpha = 0.1, maes_prefix_alpha = 2, maes_expansion_gamma = 4.3 
# Best CER Candidate = 53.57% :: Beam size = 8, Beam alpha = 0.1,  maes_prefix_alpha = 2, maes_expansion_gamma = 4.3
# =================================================================================
# Out:
# PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py nemo_model_file=/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo input_manifest=/mnt/ssd8/chime7/eval/dipco/ref_with_pred.json acoustic_batch_size=16 kenlm_model_file=/mnt/ssd8/chime7/lms/7gram_0001.kenlm beam_width=[8] beam_alpha=[0.1] maes_prefix_alpha=[2] maes_expansion_gamma=[4.3] preds_output_folder=/mnt/ssd8/chime7/eval/dipco/predict/ decoding_strategy=maes

# %%
! echo PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov \
python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py \
nemo_model_file=$rnnt_nemo \
input_manifest=/mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json \
acoustic_batch_size=16 \
kenlm_model_file=$kenlm_train \
beam_width=[8] \
beam_alpha=[0.1] \
maes_prefix_alpha=[2] \
maes_expansion_gamma=[4.3] \
preds_output_folder=/mnt/ssd8/chime7/eval/mixer6/predict/ \
decoding_strategy=maes
# greedy mixer6 WER/CER 28.3%/22.96%
# WER/CER with maes decoding and N-gram model = 27.65%/22.36%
# Oracle WER/CER in candidates with perfect LM= 23.99%/19.89%
# =================================================================================
# Best WER Candidate = 27.65% :: Beam size = 8, Beam alpha = 0.1, maes_prefix_alpha = 2, maes_expansion_gamma = 4.3 
# Best CER Candidate = 22.36% :: Beam size = 8, Beam alpha = 0.1,  maes_prefix_alpha = 2, maes_expansion_gamma = 4.3
# =================================================================================
# Out:
# PYTHONPATH=/home/nkarpov/workspace/NeMo:/home/nkarpov/workspace/exprunner:/home/nkarpov/workspace/nkarpov python3 /home/nkarpov/workspace/NeMo/scripts/asr_language_modeling/ngram_lm/eval_beamsearch_ngram_transducer.py nemo_model_file=/mnt/ssd8/chime7/rno_chime7_chime6_ft_ptDataSetasrset3_frontend_nemoGSSv1_prec32_layers24_heads8_conv5_d1024_dlayers2_dsize640_bs128_adamw_CosineAnnealing_lr0.0001_wd1e-2_spunigram1024.nemo input_manifest=/mnt/ssd8/chime7/eval/mixer6/ref_with_pred.json acoustic_batch_size=16 kenlm_model_file=/mnt/ssd8/chime7/lms/7gram_0001.kenlm beam_width=[8] beam_alpha=[0.1] maes_prefix_alpha=[2] maes_expansion_gamma=[4.3] preds_output_folder=/mnt/ssd8/chime7/eval/mixer6/predict/ decoding_strategy=maes
